# %% [markdown]
# ##Exercise
# Goal: Extract job title, job link, brief description provided.
#
# Bonus: Place in Pandas dataframe and print
#
# Website URL : https://pythonjobs.github.io/

# %%
#Load packages
# !pip install bs4
# !pip install pandas
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.4.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=8d220f404178ce81af215d431d16a1d9c09c9546208b04c4351e0988177ee998
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
#get webpage html.
html = urlopen('https://pythonjobs.github.io/')
bs_html = BeautifulSoup(html, 'html.parser')

# %%
#Inspect elements of website. Want to extract div tag of class 'job'
titles = bs_html.find_all('div', {'class': 'job'})
#Create empty lists. Will store desired information inside them.
title = []
links = []
location = []
description = []
for item in titles:
    #Loop through all tags found from above. Find title of position
    title1 = item.find('h1')
    #append job title to list
    title.append(title1.get_text())
    #Find links to more detail for position.
    #Pull description.
    desc = item.find('p', {'class': 'detail'})
    description.append(desc.get_text())
    link = item.find('a', {'class': 'go_button'})
    #Append link attribute href to list. 'href' if hyperlink.
    links.append(link['href'])

    #extra. Location
    #Location, is trickier. Inspecting webpage i tag
    loc = item.find('i', {'class':'i-globe'})
    #Get text of parent html element.
    loc = loc.parent.get_text()
    #Append to list.
    location.append(loc)

# %%
data = pd.DataFrame({
    'title': title,
    'link': links,
    'desc': description,
    'loc': location

})
display(data)
# Out:
#                                          title  \
# 0                      Strats Python Developer
# 1                    Python Software Developer
# 2  Senior Software Engineer, Back-End (Remote)
# 3                      Python Backend Engineer
# 4                      Senior Backend Engineer
#
#                                                 link  \
# 0                    /jobs/hbk-strats-developer.html
# 1  /jobs/open-data-services-co-operative-python-s...
# 2  /jobs/oomnitza-back-end-sw-enginneer-irl-remot...
# 3            /jobs/bmat-python-backend-engineer.html
# 4            /jobs/bmat-senior-backend-engineer.html
#
#                                                 desc                       loc
# 0   Overview HBK is searching for a Python softwa...                London, UK
# 1   We’re hiring a Python Software Developer to j...           Remote, UK-only
# 2   Oomnitza offers enterprise IT a unique soluti...   Galway, Ireland, Remote
# 3   What you’ll be doing In the Data team we want...                    Remote
# 4   What you’ll be doing BMAT is teaming up with ...                    Remote
